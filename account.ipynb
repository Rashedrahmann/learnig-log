# %%
pin = "1234"
balance = 5000
mini_statement = ["50 Deposit", "20 Withdrawal"]
# Out:
# login successful

# %%
#Function for checking PIN
def authenticate():
    entered_pin = input("Enter your PIN : ")
    if entered_pin == pin:
        print("login successful")
        return True
    else:
        print("Incorrect PIN")
        return False
store_return = authenticate()
if store_return == True:
    print("Welcome! Here is your mini statement:")
    print(mini_statement)
else:
     print("Try again")
# Out:
# login successful
# Welcome! Here is your mini statement:
# ['$50 Deposit', '$20 Withdrawal']

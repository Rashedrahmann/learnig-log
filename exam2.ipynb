# %% [markdown]
# <a href="https://colab.research.google.com/github/Rashedrahmann/learnig-log/blob/Rashed/exam2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Answer Question 1(1)**

# %%
import pandas as pd
import numpy as np

# %%
pip install openpyxl

# %%
raw=pd.read_excel('/content/Churn.xlsx')

# %%
df=raw.copy()

# %%
df.head(20)
# Out:
#    CustomerID     Age  Gender   Region  PlanType MonthlyCharges TenureMonths  \
# 0       C0001  __35__    Male    South     Basic          16.62            2
# 1       C0002      26    Male    North  Standard          46.23        __4__
# 2       C0003      31  Female    North  Standard          43.04           32
# 3       C0004      34    Male     East     Basic          29.19           20
# 4       C0005      38  Female    North     Basic          24.95            1
# 5       C0006      36  Female     East  Standard          47.99           11
# 6       C0007      28  Female     West  Standard          37.51           64
# 7       C0008      58    Male  Central  Standard          37.32           13
# 8       C0009      26    Male     East   Premium           69.6           33
# 9       C0010      23    Male  Central  Standard          43.56            5
# 10      C0011      29    Male    South     Basic          27.07           23
# ...

# %%
df.isnull().sum()
# Out:
# CustomerID                0
# Age                      72
# Gender                   68
# Region                   52
# PlanType                 55
# MonthlyCharges          112
# TenureMonths             60
# SupportTickets           66
# AvgMonthlyUsageHours     98
# ContractType             69
# PaymentMethod            54
# AutoPay                  60
# SatisfactionScore        78
# LastLoginDays            47
# ReferralCount            25
# DeviceCount              32
# Churn                     0
# dtype: int64

# %%
df['Age'].isna().sum()
# Out:
# np.int64(72)

# %%
df['Age'].isna().mean()
# Out:
# np.float64(0.02057142857142857)

# %%
df.head(10)
# Out:
#   CustomerID     Age  Gender   Region  PlanType MonthlyCharges TenureMonths  \
# 0      C0001  __35__    Male    South     Basic          16.62            2
# 1      C0002      26    Male    North  Standard          46.23        __4__
# 2      C0003      31  Female    North  Standard          43.04           32
# 3      C0004      34    Male     East     Basic          29.19           20
# 4      C0005      38  Female    North     Basic          24.95            1
# 5      C0006      36  Female     East  Standard          47.99           11
# 6      C0007      28  Female     West  Standard          37.51           64
# 7      C0008      58    Male  Central  Standard          37.32           13
# 8      C0009      26    Male     East   Premium           69.6           33
# 9      C0010      23    Male  Central  Standard          43.56            5
#
#   SupportTickets AvgMonthlyUsageHours ContractType  PaymentMethod AutoPay  \
# ...

# %%
df['Age'].isna().sum()
# Out:
# np.int64(72)

# %%
df['Age'] = df['Age'].astype(str).str.strip().str.replace(r'[^a-zA-Z0-9]','',regex=True)

# %%
df['Age'].isna().sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#   CustomerID Age  Gender Region  PlanType MonthlyCharges TenureMonths  \
# 0      C0001  35    Male  South     Basic          16.62            2
# 1      C0002  26    Male  North  Standard          46.23        __4__
# 2      C0003  31  Female  North  Standard          43.04           32
# 3      C0004  34    Male   East     Basic          29.19           20
# 4      C0005  38  Female  North     Basic          24.95            1
#
#   SupportTickets AvgMonthlyUsageHours ContractType  PaymentMethod AutoPay  \
# 0              5             __27.0__    Quarterly           Card     Yes
# 1              0                 46.1      Monthly            UPI     Yes
# 2              0                 27.2          NaN            UPI     Yes
# 3              4                 25.1      Monthly  Bank Transfer     Yes
# 4              4                   49      Monthly           Cash      No
#
#   SatisfactionScore LastLoginDays ReferralCount DeviceCount  Churn
# ...

# %%
df['TenureMonths'] = df['TenureMonths'].astype(str).str.strip().str.replace(r'[^a-zA-Z0-9]','',regex=True)

# %%
df['AvgMonthlyUsageHours'] = df['AvgMonthlyUsageHours'].astype(str).str.strip().str.replace(r'[^a-zA-Z0-9]','',regex=True)

# %%
dupe_customerid = df.duplicated(['CustomerID']).sum()

# %%
dupe_customerid
# Out:
# np.int64(0)

# %%
dupe_Age=df.duplicated(['Age']).sum()
dupe_Age
# Out:
# np.int64(3445)

# %%
df['PaymentMethod'] = df['PaymentMethod'].fillna(df['PaymentMethod'].mode())

# %%
df.head()
# Out:
#   CustomerID Age  Gender Region  PlanType MonthlyCharges TenureMonths  \
# 0      C0001  35    Male  South     Basic          16.62            2
# 1      C0002  26    Male  North  Standard          46.23            4
# 2      C0003  31  Female  North  Standard          43.04           32
# 3      C0004  34    Male   East     Basic          29.19           20
# 4      C0005  38  Female  North     Basic          24.95            1
#
#   SupportTickets AvgMonthlyUsageHours ContractType  PaymentMethod AutoPay  \
# 0              5                  270    Quarterly           Card     Yes
# 1              0                  461      Monthly            UPI     Yes
# 2              0                  272          NaN            UPI     Yes
# 3              4                  251      Monthly  Bank Transfer     Yes
# 4              4                   49      Monthly           Cash      No
#
#   SatisfactionScore LastLoginDays ReferralCount DeviceCount  Churn
# ...

# %%
df['ContractType'] = df['ContractType'].fillna(df['ContractType'].mode())

# %%
duplicates = df[df.duplicated(keep=False)]

# %%
customer_id_duplicates = df[df.duplicated("CustomerID", keep=False)]

# %%
customer_id_duplicates
# Out:
# Empty DataFrame
# Columns: [CustomerID, Age, Gender, Region, PlanType, MonthlyCharges, TenureMonths, SupportTickets, AvgMonthlyUsageHours, ContractType, PaymentMethod, AutoPay, SatisfactionScore, LastLoginDays, ReferralCount, DeviceCount, Churn]
# Index: []

# %%
con_duplicates=df.duplicated().sum()

# %%
con_duplicates
# Out:
# np.int64(0)

# %%
customer_id_duplicates = df[df.duplicated("CustomerID", keep=False)]

customer_id_duplicates
# Out:
# Empty DataFrame
# Columns: [CustomerID, Age, Gender, Region, PlanType, MonthlyCharges, TenureMonths, SupportTickets, AvgMonthlyUsageHours, ContractType, PaymentMethod, AutoPay, SatisfactionScore, LastLoginDays, ReferralCount, DeviceCount, Churn]
# Index: []

# %% [markdown]
# **Answer question1(2)**

# %%
df.head(10)
# Out:
#   CustomerID Age  Gender   Region  PlanType MonthlyCharges TenureMonths  \
# 0      C0001  35    Male    South     Basic          16.62            2
# 1      C0002  26    Male    North  Standard          46.23            4
# 2      C0003  31  Female    North  Standard          43.04           32
# 3      C0004  34    Male     East     Basic          29.19           20
# 4      C0005  38  Female    North     Basic          24.95            1
# 5      C0006  36  Female     East  Standard          47.99           11
# 6      C0007  28  Female     West  Standard          37.51           64
# 7      C0008  58    Male  Central  Standard          37.32           13
# 8      C0009  26    Male     East   Premium           69.6           33
# 9      C0010  23    Male  Central  Standard          43.56            5
#
#   SupportTickets AvgMonthlyUsageHours ContractType  PaymentMethod AutoPay  \
# 0              5                  270    Quarterly           Card     Yes
# ...

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Reload original dataset
df = pd.read_excel("Churn.xlsx")

# Find categorical columns
categorical_columns = df.select_dtypes(include=['object']).columns

# Encode categorical columns
for col in categorical_columns:
    df[col] = df[col].astype(str)
    encoder = LabelEncoder()
    df[col] = encoder.fit_transform(df[col])

df.head()
# Out:
#    CustomerID  Age  Gender  Region  PlanType  MonthlyCharges  TenureMonths  \
# 0           0   64       1       3         3             349            12
# 1           1    9       1       2         5            1571            83
# 2           2   14       0       2         5            1421            26
# 3           3   17       1       1         3             858            13
# 4           4   21       0       2         3             707             1
#
#    SupportTickets  AvgMonthlyUsageHours  ContractType  PaymentMethod  AutoPay  \
# 0               8                   664             4              1        3
# 1               1                   381             3              3        3
# 2               1                   189             7              3        3
# 3               7                   168             3              0        3
# 4               7                   410             3              2        2
#
# ...

# %%
from sklearn.preprocessing import StandardScaler

# Select numerical columns
numeric_columns = df.select_dtypes(include=['int64', 'float64']).columns

# Exclude CustomerID if it is numeric
numeric_columns = numeric_columns.drop('CustomerID', errors='ignore')

# Create scaler
scaler = StandardScaler()

# Scale numerical features
df[numeric_columns] = scaler.fit_transform(df[numeric_columns])

# Check the result
df.head()
# Out:
#    CustomerID       Age    Gender    Region  PlanType  MonthlyCharges  \
# 0           0  2.856273  0.426474  0.574828 -0.716318       -1.280500
# 1           1 -0.852822  0.426474 -0.066312  0.879045        0.270781
# 2           2 -0.515632 -0.785101 -0.066312  0.879045        0.080362
# 3           3 -0.313317  0.426474 -0.707452 -0.716318       -0.634345
# 4           4 -0.043565 -0.785101 -0.066312 -0.716318       -0.826033
#
#    TenureMonths  SupportTickets  AvgMonthlyUsageHours  ContractType  \
# 0     -0.681338        0.587543              2.036038      0.282474
# 1      2.227811       -1.232970              0.112206     -0.529233
# 2     -0.107703       -1.232970             -1.193009      2.717596
# 3     -0.640364        0.327469             -1.335767     -0.529233
# 4     -1.132051        0.327469              0.309348     -0.529233
#
#    PaymentMethod   AutoPay  SatisfactionScore  LastLoginDays  ReferralCount  \
# ...

# %%
df.describe()
# Out:
#         CustomerID           Age        Gender        Region      PlanType  \
# count  3500.000000  3.500000e+03  3.500000e+03  3.500000e+03  3.500000e+03
# mean   1749.500000 -6.090366e-17 -8.323501e-17 -1.177471e-16 -1.086115e-16
# std    1010.507298  1.000143e+00  1.000143e+00  1.000143e+00  1.000143e+00
# min       0.000000 -1.459765e+00 -7.851006e-01 -1.348592e+00 -3.109363e+00
# 25%     874.750000 -6.505079e-01 -7.851006e-01 -7.074523e-01 -7.163180e-01
# 50%    1749.500000 -1.110031e-01  4.264744e-01 -6.631221e-02  8.136352e-02
# 75%    2624.250000  4.285017e-01  4.264744e-01  5.748279e-01  8.790451e-01
# max    3499.000000  3.935283e+00  5.272774e+00  3.139388e+00  3.272090e+00
#
#        MonthlyCharges  TenureMonths  SupportTickets  AvgMonthlyUsageHours  \
# count    3.500000e+03  3.500000e+03    3.500000e+03          3.500000e+03
# mean     1.096266e-16 -8.678772e-17   -6.293379e-17          1.329730e-16
# ...

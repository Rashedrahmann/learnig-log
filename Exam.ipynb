# %% [markdown]
# <a href="https://colab.research.google.com/github/Rashedrahmann/learnig-log/blob/Rashed/Exam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Q2. A. Purpose of the Head is to see the label of the Dataset , and get idea begining of data structure .

# %% [markdown]
# B. info command constructs a concise report of the data frame

# %% [markdown]
# C. **Describe** command gives us the 'Median' 'Max' 'Min' values of the dataset.*italicized text*

# %% [markdown]
# D.**Value count** is a built-in method used to count the frequency of unique values within a Series or a DataFrame column.

# %% [markdown]
# Q3. **.loc** uses the literal name of the data series or dataframe, **.iloc**  uses the 0-based integer positions of rows and columns.

# %% [markdown]
# Q1. **Series**: A Series is a one-dimensional and the array are labeled. Emaple: a single column in an Excel sheet,**Datafram**:DataFrame is a two-dimensional, table-like data structure. Example: the entire spreadsheet.

# %% [markdown]
# Q4. A. To visualize the distribution of Age Histogram is the best choice.

# %% [markdown]
# B. Scatterplot is the best choice for the visualize the between height and weight.

# %% [markdown]
# C. Bar chart is the best option to visualize the number of students each Department.To visualize the Number of Students in Each Department. A bar chart clearly illustrates the exact count for each distinct group.Easy to Read: The human eye can easily compare the lengths of the bars to determine which departments are the largest or smallest at a glance.

# %% [markdown]
# D.For visualizing the correlation among numerical features, the best choice is a correlation heatmap. Each cell represents the intersection of two features, and the color intensity indicates the strength and direction (positive or negative) of the relationship.

# %%
import pandas as pd
import seaborn as sns
import requests

# %%
url = "https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/0e7a9b0a5d22642a06d3d5b9bcbad9890c8ee534/iris.csv"

# %%
data = sns.load_dataset("iris")

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#Check the information
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
#Check dataset missing value
data.isnull().values.any()
# Out:
# np.False_

# %%
# Check the numerical columns
numerical_cols = data.select_dtypes(include=['number']).columns

# Check the categorical columns
categorical_cols = data.select_dtypes(include=['object', 'category']).columns

print("Numerical Columns:", numerical_cols)
print("Categorical Columns:", categorical_cols)
# Out:
# Numerical Columns: Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width'], dtype='object')
# Categorical Columns: Index(['species'], dtype='object')

# %% [markdown]
# Q5. Overfitting is when model acts more accordingly on training data with all its noise and complexity. It performs perfectly on training data but poorly on new data. Underfitting is when the model performs poorly on both traning and new data.

# %% [markdown]
# Q6.**Fit** computes and stores the internal parameters (like mean and standard deviation) from a dataset
# **Fit_transform** computes these parameters and immediately applies the transformation to return the modified data in a single, optimized step

# %% [markdown]
# Q7.**Linear Regression** predicts continuous numerical values by fitting a straight line to the data.
#
# **Logistic Regression** predicts categorical outcomes and probabilities (e.g., yes/no spam) by passing linear outputs through an S-shaped activation function.
